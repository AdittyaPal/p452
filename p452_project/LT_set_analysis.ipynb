# %% [markdown]
# #  ANALYSING RESULTS OF THE SET OF SIMULATIONS

# %% [markdown]
# ## Loading results of the simulation

# %%
# %matplotlib notebook

# %%
import numpy as np
from scipy import stats

import matplotlib.pyplot as plt
import seaborn as sns

from thermalspin.data_analysis  import *

# %%
#the name of the simulation set
setname = "sim_2d"
out_dir = f"./plots/{setname}/"
os.makedirs(out_dir, exist_ok=True)

# %%
final_state_lst, L_lst, t_lst, J_lst, D_lst, h_lst, T_lst, E_lst, m_lst, snp_lst = load_set_results(setname)
# Out:
# sim_2d_T0.250_L16_H0.000 loaded
# sim_2d_T0.250_L20_H0.000 loaded
# sim_2d_T0.250_L24_H0.000 loaded
# sim_2d_T0.250_L28_H0.000 loaded
# sim_2d_T0.250_L32_H0.000 loaded
# sim_2d_T0.300_L16_H0.000 loaded
# sim_2d_T0.300_L20_H0.000 loaded
# sim_2d_T0.300_L24_H0.000 loaded
# sim_2d_T0.300_L28_H0.000 loaded
# sim_2d_T0.300_L32_H0.000 loaded
# sim_2d_T0.350_L16_H0.000 loaded
# sim_2d_T0.350_L20_H0.000 loaded
# sim_2d_T0.350_L24_H0.000 loaded
# sim_2d_T0.350_L28_H0.000 loaded
# sim_2d_T0.350_L32_H0.000 loaded
# sim_2d_T0.400_L16_H0.000 loaded
# sim_2d_T0.400_L20_H0.000 loaded
# sim_2d_T0.400_L24_H0.000 loaded
# sim_2d_T0.400_L28_H0.000 loaded
# sim_2d_T0.400_L32_H0.000 loaded
# sim_2d_T0.450_L16_H0.000 loaded
# sim_2d_T0.450_L20_H0.000 loaded
# sim_2d_T0.450_L24_H0.000 loaded
# sim_2d_T0.450_L28_H0.000 loaded
# sim_2d_T0.450_L32_H0.000 loaded
# sim_2d_T0.500_L16_H0.000 loaded
# sim_2d_T0.500_L20_H0.000 loaded
# sim_2d_T0.500_L24_H0.000 loaded
# sim_2d_T0.500_L28_H0.000 loaded
# sim_2d_T0.500_L32_H0.000 loaded
# sim_2d_T0.550_L16_H0.000 loaded
# sim_2d_T0.550_L20_H0.000 loaded
# sim_2d_T0.550_L24_H0.000 loaded
# sim_2d_T0.550_L28_H0.000 loaded
# sim_2d_T0.550_L32_H0.000 loaded
# sim_2d_T0.600_L16_H0.000 loaded
# sim_2d_T0.600_L20_H0.000 loaded
# sim_2d_T0.600_L24_H0.000 loaded
# sim_2d_T0.600_L28_H0.000 loaded
# sim_2d_T0.600_L32_H0.000 loaded
# sim_2d_T0.650_L16_H0.000 loaded
# sim_2d_T0.650_L20_H0.000 loaded
# sim_2d_T0.650_L24_H0.000 loaded
# sim_2d_T0.650_L28_H0.000 loaded
# sim_2d_T0.650_L32_H0.000 loaded
# sim_2d_T0.700_L16_H0.000 loaded
# sim_2d_T0.700_L20_H0.000 loaded
# sim_2d_T0.700_L24_H0.000 loaded
# sim_2d_T0.700_L28_H0.000 loaded
# sim_2d_T0.700_L32_H0.000 loaded
# sim_2d_T0.750_L16_H0.000 loaded
# sim_2d_T0.750_L20_H0.000 loaded
# sim_2d_T0.750_L24_H0.000 loaded
# sim_2d_T0.750_L28_H0.000 loaded
# sim_2d_T0.750_L32_H0.000 loaded
# sim_2d_T0.800_L16_H0.000 loaded
# sim_2d_T0.800_L20_H0.000 loaded
# sim_2d_T0.800_L24_H0.000 loaded
# sim_2d_T0.800_L28_H0.000 loaded
# sim_2d_T0.800_L32_H0.000 loaded
# sim_2d_T0.850_L16_H0.000 loaded
# sim_2d_T0.850_L20_H0.000 loaded
# sim_2d_T0.850_L24_H0.000 loaded
# sim_2d_T0.850_L28_H0.000 loaded
# sim_2d_T0.850_L32_H0.000 loaded
# sim_2d_T0.900_L16_H0.000 loaded
# sim_2d_T0.900_L20_H0.000 loaded
# sim_2d_T0.900_L24_H0.000 loaded
# sim_2d_T0.900_L28_H0.000 loaded
# sim_2d_T0.900_L32_H0.000 loaded
# sim_2d_T0.950_L16_H0.000 loaded
# sim_2d_T0.950_L20_H0.000 loaded
# sim_2d_T0.950_L24_H0.000 loaded
# sim_2d_T0.950_L28_H0.000 loaded
# sim_2d_T0.950_L32_H0.000 loaded
# sim_2d_T1.000_L16_H0.000 loaded
# sim_2d_T1.000_L20_H0.000 loaded
# sim_2d_T1.000_L24_H0.000 loaded
# sim_2d_T1.000_L28_H0.000 loaded
# sim_2d_T1.000_L32_H0.000 loaded
# sim_2d_T1.050_L16_H0.000 loaded
# sim_2d_T1.050_L20_H0.000 loaded
# sim_2d_T1.050_L24_H0.000 loaded
# sim_2d_T1.050_L28_H0.000 loaded
# sim_2d_T1.050_L32_H0.000 loaded
# sim_2d_T1.100_L16_H0.000 loaded
# sim_2d_T1.100_L20_H0.000 loaded
# sim_2d_T1.100_L24_H0.000 loaded
# sim_2d_T1.100_L28_H0.000 loaded
# sim_2d_T1.100_L32_H0.000 loaded
# sim_2d_T1.150_L16_H0.000 loaded
# sim_2d_T1.150_L20_H0.000 loaded
# sim_2d_T1.150_L24_H0.000 loaded
# sim_2d_T1.150_L28_H0.000 loaded
# sim_2d_T1.150_L32_H0.000 loaded
# sim_2d_T1.200_L16_H0.000 loaded
# sim_2d_T1.200_L20_H0.000 loaded
# sim_2d_T1.200_L24_H0.000 loaded
# sim_2d_T1.200_L28_H0.000 loaded
# sim_2d_T1.200_L32_H0.000 loaded
# sim_2d_T1.250_L16_H0.000 loaded
# sim_2d_T1.250_L20_H0.000 loaded
# sim_2d_T1.250_L24_H0.000 loaded
# sim_2d_T1.250_L28_H0.000 loaded
# sim_2d_T1.250_L32_H0.000 loaded
# sim_2d_T1.300_L16_H0.000 loaded
# sim_2d_T1.300_L20_H0.000 loaded
# sim_2d_T1.300_L24_H0.000 loaded
# sim_2d_T1.300_L28_H0.000 loaded
# sim_2d_T1.300_L32_H0.000 loaded
# sim_2d_T1.350_L16_H0.000 loaded
# sim_2d_T1.350_L20_H0.000 loaded
# sim_2d_T1.350_L24_H0.000 loaded
# sim_2d_T1.350_L28_H0.000 loaded
# sim_2d_T1.350_L32_H0.000 loaded
# sim_2d_T1.400_L16_H0.000 loaded
# sim_2d_T1.400_L20_H0.000 loaded
# sim_2d_T1.400_L24_H0.000 loaded
# sim_2d_T1.400_L28_H0.000 loaded
# sim_2d_T1.400_L32_H0.000 loaded
# sim_2d_T1.450_L16_H0.000 loaded
# sim_2d_T1.450_L20_H0.000 loaded
# sim_2d_T1.450_L24_H0.000 loaded
# sim_2d_T1.450_L28_H0.000 loaded
# sim_2d_T1.450_L32_H0.000 loaded
# sim_2d_T1.500_L16_H0.000 loaded
# sim_2d_T1.500_L20_H0.000 loaded
# sim_2d_T1.500_L24_H0.000 loaded
# sim_2d_T1.500_L28_H0.000 loaded
# sim_2d_T1.500_L32_H0.000 loaded
# sim_2d_T1.550_L16_H0.000 loaded
# sim_2d_T1.550_L20_H0.000 loaded
# sim_2d_T1.550_L24_H0.000 loaded
# sim_2d_T1.550_L28_H0.000 loaded
# sim_2d_T1.550_L32_H0.000 loaded
# sim_2d_T1.600_L16_H0.000 loaded
# sim_2d_T1.600_L20_H0.000 loaded
# sim_2d_T1.600_L24_H0.000 loaded
# sim_2d_T1.600_L28_H0.000 loaded
# sim_2d_T1.600_L32_H0.000 loaded
# sim_2d_T1.650_L16_H0.000 loaded
# sim_2d_T1.650_L20_H0.000 loaded
# sim_2d_T1.650_L24_H0.000 loaded
# sim_2d_T1.650_L28_H0.000 loaded
# sim_2d_T1.650_L32_H0.000 loaded
# sim_2d_T1.700_L16_H0.000 loaded
# sim_2d_T1.700_L20_H0.000 loaded
# sim_2d_T1.700_L24_H0.000 loaded
# sim_2d_T1.700_L28_H0.000 loaded
# sim_2d_T1.700_L32_H0.000 loaded

# %%
L, T, t_whole, J_whole, D_whole, h_whole, E_whole, m_whole, final_state, snp = arrange_set_results_LT(L_lst, t_lst, J_lst, D_lst, h_lst, T_lst, E_lst, m_lst, final_state_lst)
L_num = t_whole.shape[0]
T_num = t_whole.shape[1]
t_num = t_whole.shape[2]

# %% [markdown]
# ## Global behaviour

# %%
fig = plt.figure(figsize=(10,6))
ax = plt.subplot(111)
for i in range(L_num):
    ax.plot(t_whole[i,1], E_whole[i,1], label=f"L = {L[i]}, T = {T[1]}")
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5), prop={'size': 6})
plt.xlabel("Steps")
plt.ylabel("Energy")
plt.grid()
plt.show()
#fig.savefig("./plots/"+setname+"_energy.svg")
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
m_magnitude_whole = np.sqrt(np.sum(m_whole**2, axis = 3))

# %%
fig = plt.figure(figsize=(10,6))
ax = plt.subplot(111)
for i in range(L_num):
    ax.plot(t_whole[i,1], m_magnitude_whole[i,1], label=f"L = {L[i]}, T = {T[1]}")
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5), prop={'size': 6})
plt.xlabel("Steps")
plt.ylabel("Absolute magnetization")
plt.grid()
plt.show()
#fig.savefig("./plots/"+setname+"_magnetization_ordered.svg")
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# ## Single ensemble analysis

# %%
# Insert here index of the ensemble to be analyzed 
L_idx = 1
T_idx = 1

# %%
fig = plt.figure(figsize=(10,6))
ax = plt.subplot(111)
ax.plot(t_whole[L_idx, T_idx], E_whole[L_idx, T_idx], label=f"L = {L[L_idx]}, T = {T[T_idx]}")
ax.legend()
plt.ylabel("Energy")
plt.xlabel("Steps")
plt.title("Energy")
plt.grid()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
fig = plt.figure(figsize=(10,6))
ax = plt.subplot(111)
ax.plot(t_whole[L_idx, T_idx], m_whole[L_idx, T_idx, :, 0], label = r"$M_x$")
ax.plot(t_whole[L_idx, T_idx], m_whole[L_idx, T_idx, :, 1], label = r"$M_y$")
ax.plot(t_whole[L_idx, T_idx], m_whole[L_idx, T_idx, :, 2], label = r"$M_z$")
plt.legend()
plt.ylabel("Magnetization")
plt.xlabel("Steps")
plt.title(f"Magnetization, L = {L[L_idx]}, T = {T[T_idx]}")
plt.grid()
plt.show()
#fig.savefig("./plots/"+setname+"_magnetization_ordered_components.svg")
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
fig = plt.figure(figsize=(10,6))
ax = plt.subplot(111)
ax.plot(t_whole[L_idx, T_idx], np.abs(m_whole[L_idx, T_idx, :, 0]), label = r"$|M_x|$")
ax.plot(t_whole[L_idx, T_idx], np.abs(m_whole[L_idx, T_idx, :, 1]), label = r"$|M_y|$")
ax.plot(t_whole[L_idx, T_idx], np.abs(m_whole[L_idx, T_idx, :, 2]), label = r"$|M_z|$")
plt.legend()
plt.ylabel("Absolute magnetization")
plt.xlabel("Steps")
plt.title("Absolute magnetization")
plt.grid()
plt.show()
#fig.savefig("./plots/"+setname+"_magnetization_ordered_components.svg")
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
L_idx = -1
T_idx = 0

# %%
fig, ax = plot_state(final_state[L_idx][T_idx], hls = False)
ax.view_init(elev=30, azim=-60)
plt.title(f"Alignment of the spins at T = {T[T_idx]}")
fig.show()
#fig.savefig(out_dir+f"ordered_state.svg")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig, ax = plot_state_2D(final_state[L_idx][T_idx], hls = False)
ax.view_init(elev=30, azim=-60)
plt.title(f"Alignment of the spins at T = {T[T_idx]}")
fig.show()
#fig.savefig(out_dir+f"ordered_state.svg")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig, ax = plot_spin_directions(final_state[L_idx][T_idx], hls = False)
ax.view_init(elev=30, azim=-60)
plt.title(r"Direction of spins near $T_{crit}$"+ f"T = {T[T_idx]}")
fig.show()
#fig.savefig(out_dir+"direction_T_crit.svg")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Variation with temperature

# %%
# SELECT WARMUP PERIOD TO LAST UNTIL STEP NUMBER warmup_final_step
warmup_end = 0.5e7
warmup_final_idx = np.argmax(np.equal(t_whole[0,0], warmup_end))
final_idx=-1
t = t_whole[:, :, warmup_final_idx:final_idx]
E = E_whole[:, :, warmup_final_idx:final_idx]
m = m_whole[:, :, warmup_final_idx:final_idx]

# %%
E_mean = np.mean(E, axis=2)
E_std = np.sqrt(np.var(E, axis=2))

e_mean = np.zeros(shape=E_mean.shape)
e_std = np.zeros(shape=E_std.shape)
for i in range(L_num):
    e_mean[i] = E_mean[i]/L[i]**3
    e_std[i] = E_std[i]/L[i]**3

# %%
L_idx = 1
T_idx = 1

fig = plt.figure(figsize=(8,5))
E_tbp=E[L_idx,T_idx]
sns.histplot(E_tbp)
plt.xlabel("Energy")
plt.ylabel("Frequency")
plt.title(f"Distribution of energy of the system for L = {L[L_idx]}, T = {str(T[T_idx])}")
plt.grid()
plt.show()
#fig.savefig("./plots/"+setname+"_distribution.svg")
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# ### Mean energy

# %%
fig = plt.figure(figsize=(8,5))
ax = plt.subplot(111)
for i in np.ndindex(L_num):
    ax.errorbar(T, E_mean[i], yerr=E_std[i]/2, fmt="--.", label=f"L = {L[i]}")
box = ax.get_position()
ax.legend()
plt.title(r"Variation of $\langle E \rangle$ with $T$")
plt.xlabel(r"$T$")
plt.ylabel(r"$\langle E \rangle$")
plt.grid()
plt.show()
#fig.savefig("./plots/"+setname+"_energy_temperature.svg")
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
fig = plt.figure(figsize=(8,5))
ax = plt.subplot(111)
for i in range(L_num):
    ax.errorbar(T, e_mean[i], yerr=e_std[i]/2, fmt="--.", label=f"L = {L[i]}")
box = ax.get_position()
ax.legend()
plt.title(r"Variation of $\langle E \rangle$/per spin with $T$")
plt.xlabel(r"$T$")
plt.ylabel(r"$\langle E \rangle/N$")
plt.grid()
plt.show()
#fig.savefig("./plots/"+setname+"_energy_per_spin.svg")
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# ### Mean magnetization magnitude

# %%
m_mean = np.mean(m, axis=2)
m_std = np.sqrt(np.var(m, axis=2))
m_magnitude = np.sqrt(np.sum(m**2, axis = 3))
m_magnitude_mean = np.mean(m_magnitude, axis=2)
m_magnitude_std = np.sqrt(np.var(m_magnitude, axis=2))

# %%
fig = plt.figure(figsize=(8,5))
ax = plt.subplot(111)
for i in range(L_num):
    ax.errorbar(T, m_magnitude_mean[i], yerr=m_magnitude_std[i]/2,fmt="--.", label=f"L = {L[i]}")
box = ax.get_position()
ax.legend()
plt.xlabel(r"$T$")
plt.ylabel(r"$\langle | \vec{M} | \rangle$")
plt.grid()
plt.title("Vatiation of Expectation value for magnitude magnetization with temperature")
plt.show()
#fig.savefig("./plots/"+setname+"_magnetization_magnitude.svg")
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# ### Heat capacity

# %%
E_var = np.var(E, axis=2)

# %%
cv = np.zeros(shape=(L_num, T_num))
for i in np.ndindex(L_num):
    cv[i] = E_var[i]/T**2/L[i]**3

# %%
fig = plt.figure(figsize=(8,5))
ax = plt.subplot(111)
for i in range(L_num):
    ax.plot(T, cv[i], ":.", label=f"L = {L[i]}")
box = ax.get_position()
ax.legend()
plt.xlabel("Temperature")
plt.ylabel(r"$c_v$")
plt.title("Variation of Heat capacity per spin with temperature")
plt.grid()
plt.show()
#fig.savefig("./plots/"+setname+"_heat_capacity.svg")
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# ### Suscpetibility

# %%
Tc_idx   = np.argmax(T>1.444)
T_nc_max = np.argmax(T>1.5)
T_nc_min = np.argmax(T>1.3)

T_dis = T[Tc_idx:]
T_ord = T[:Tc_idx]
T_dis_nc = T[Tc_idx:T_nc_max]
T_ord_nc = T[T_nc_min:Tc_idx]

# %%
def cov(X,i,j):
    X_mean = np.mean(X, axis=2)
    ret = np.zeros(shape=(L_num, T_num))
    for l,t in np.ndindex(L_num, T_num):
        ret[l,t] = np.mean((X[l,t,:,i]-X_mean[l,t,i])*(X[l,t,:,j]-X_mean[l,t,j]))
    return ret

# %%
chi_xx = np.zeros(shape=(L_num, T_num))
chi_yy = np.zeros(shape=(L_num, T_num))
chi_zz = np.zeros(shape=(L_num, T_num))
chi_xy = np.zeros(shape=(L_num, T_num))
chi_yz = np.zeros(shape=(L_num, T_num))
chi_zx = np.zeros(shape=(L_num, T_num))

for i in np.ndindex(L_num):
    chi_xx[i] = cov(m,0,0)[i]/T*L[i]**3
    chi_yy[i] = cov(m,1,1)[i]/T*L[i]**3
    chi_zz[i] = cov(m,2,2)[i]/T*L[i]**3
    chi_xy[i] = cov(m,0,1)[i]/T*L[i]**3
    chi_yz[i] = cov(m,1,2)[i]/T*L[i]**3
    chi_zx[i] = cov(m,2,0)[i]/T*L[i]**3

# %%
m_dis = m[:,Tc_idx:]
m_ord = m[:,:Tc_idx]

chi_xx_dis = chi_xx[:, Tc_idx:]
chi_yy_dis = chi_yy[:, Tc_idx:]
chi_zz_dis = chi_zz[:, Tc_idx:]
chi_xy_dis = chi_xy[:, Tc_idx:]
chi_yz_dis = chi_yz[:, Tc_idx:]
chi_zx_dis = chi_zx[:, Tc_idx:]

# %%
fig = plt.figure(figsize=(8,5))
ax = plt.subplot(111)
for i in np.ndindex(L_num):
    ax.plot(T[Tc_idx:], chi_zz[i][Tc_idx:], "--.", label=f"L = {L[i]}")
box = ax.get_position()
ax.legend()
plt.xlabel("Temperature")
plt.ylabel(r"$\chi_{zz}$")
plt.title("Magnetic susceptibility per spin")
plt.grid()
plt.show()
#fig.savefig("./plots/"+setname+"_susceptibility.svg")
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
L_idx = -1

fig = plt.figure(figsize=(10,6))
ax = plt.subplot(111)
ax.plot(T_dis, chi_xx_dis[L_idx], ".--", label=r"$\chi_{xx}$")
ax.plot(T_dis, chi_yy_dis[L_idx], ".--", label=r"$\chi_{yy}$")
ax.plot(T_dis, chi_zz_dis[L_idx], ".--", label=r"$\chi_{zz}$")
ax.plot(T_dis, chi_xy_dis[L_idx], ".--", label=r"$\chi_{xy}$")
ax.plot(T_dis, chi_yz_dis[L_idx], ".--", label=r"$\chi_{yz}$")
ax.plot(T_dis, chi_zx_dis[L_idx], ".--", label=r"$\chi_{zx}$")
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width, box.height])
ax.legend(loc='center left', bbox_to_anchor=(0.8, 0.5))
plt.xlabel("Temperature")
plt.ylabel(r"$\chi_{zz}$")
plt.title(f"Susceptibility for L = {L[L_idx]}")
plt.grid()
plt.show()
#fig.savefig("./plots/"+setname+f"_component_susceptibility.svg")
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# ### Binder ratio

# %%
binder = 1 - (1/3)*np.mean(m_magnitude**4, axis=2)/(np.mean(m_magnitude**2, axis=2)**2)

# %%
fig = plt.figure(figsize=(8,5))
ax = plt.subplot(111)
for i in np.ndindex(L_num):
    ax.plot(T, binder[i], '--.', label=f"L = {L[i]}")
box = ax.get_position()
ax.legend()
plt.ylabel(r"Binder ratio")
plt.xlabel(r"T")
plt.title("Binder ratio")
plt.grid()
#plt.axvline(x=1.440, color='navy', ls='--', lw=0.5)
plt.show()
#fig.savefig("plots/"+setname+"_zoom_binder.svg")
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
m2 = np.mean(m_magnitude**2, axis=2)
m4 = np.mean(m_magnitude**4, axis=2)
m2E = np.mean(E*m_magnitude**2, axis=2)
m4E = np.mean(E*m_magnitude**4, axis=2)

dbinder = (1-binder)*(E_mean - 2*m2E/m2 + m4E/m4)

# %%
fig = plt.figure(figsize=(8,5))
ax = plt.subplot(111)
for i in np.ndindex(L_num):
    ax.plot(T, dbinder[i], '--.', label=f"L = {L[i]}")
box = ax.get_position()
ax.legend()
plt.ylabel(r"$\frac{d U_L}{d \beta} $")
plt.xlabel(r"T")
plt.title("Binder ratio derivative")
plt.grid()
plt.show()
#fig.savefig("plots/"+setname+"_derivative_binder.svg")
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# ### Critical indices

# %%
Tc_idx = 2
print(T[Tc_idx])
# Out:
# 1.445

# %%
def fitParam(x, y):
    S, S_x, S_y, S_xx, S_xy = 0, 0, 0, 0, 0
    for i in range(x.shape[0]):
        S+=1
        S_x+=x[i]
        S_y+=y[i]
        S_xx+=x[i]**2
        S_xy+=x[i]*y[i]
    Delta=S*S_xx-S_x**2
    a=(S_xx*S_y-S_x*S_xy)/Delta
    b=(S*S_xy-S_x*S_y)/Delta
    var_a=S_xx/Delta
    var_b=S/Delta
    cov=-S_x/Delta
    chi2=0
    for i in range(x.shape[0]):
        chi2+=(y[i]-a-b*x[i])**2
    return a, b, var_a, var_b, cov, chi2

# %%
intercept, slope, _, std_err, _, chi2  = fitParam(np.log(L), np.log(chi_zz[:,Tc_idx]))
gamma_nu = slope
gamma_nu_u = std_err

# %%
fig = plt.figure(figsize=(8,5))
ax = plt.subplot(111)
ax.set_xscale('log')
ax.set_yscale('log')
plt.scatter(L, chi_zz[:,Tc_idx])
plt.plot(L, np.exp(intercept)*L**(slope), ":")
slope_str="{0:.3}".format(slope)
std_str="{0:.3}".format(std_err)
chi_2 = "{0:.3}".format(chi2)
plt.text(10,100,fr"$slope = {slope_str}\pm{std_str}$", fontsize=11)
plt.text(10,85,fr"$\chi^2 = {chi_2}$", fontsize=11)
plt.grid(True, which="both")
plt.xlabel(r"$L$")
plt.ylabel(r"$\chi_{zz}$")
plt.title(f"T=1.445")
plt.show()
#fig.savefig("./plots/"+setname+"_gamma_nu.svg")
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
print("gamma_nu =", gamma_nu)
print("gamma_nu_u =", gamma_nu_u)
# Out:
# gamma_nu = 1.4366323804812087
# gamma_nu_u = 0.5352315542421647

# %%
intercept, slope, _, std_err, _, chi2  = fitParam(np.log(L), np.log(m_magnitude_mean[:,Tc_idx]))
beta_nu = -slope
beta_nu_u = std_err

# %%
fig = plt.figure(figsize=(8,5))
ax = plt.subplot(111)
ax.set_xscale('log')
ax.set_yscale('log')
plt.scatter(L, m_magnitude_mean[:,Tc_idx])
plt.plot(L, np.exp(intercept)*L**(slope), ":")

slope_str="{0:.4}".format(slope)
std_str="{0:.3}".format(std_err)
chi_2 = "{0:.3}".format(chi2)
plt.text(15,4e-1,fr"$slope = {slope_str}\pm{std_str}$", fontsize=11)
plt.text(15,3.8e-1,fr"$\chi^2 = {chi_2}$", fontsize=11)
plt.grid(True, which="both")
plt.xlabel(r"$L$")
plt.ylabel(r"$\langle m\rangle$")
plt.title(f"T=1.445")
plt.show()
#fig.savefig("./plots/"+setname+"_beta_nu.svg")
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
print("beta_nu =", beta_nu)
print("beta_nu_u =", beta_nu_u)
# Out:
# beta_nu = 0.6080445970352498
# beta_nu_u = 0.035596021579645296

# %%
intercept, slope, _, std_err, _, chi2  = fitParam(np.log(L), np.log(np.abs(dbinder[:,Tc_idx])))
nu_u = std_err

# %%
fig = plt.figure(figsize=(8,5))
ax = plt.subplot(111)
ax.set_xscale('log')
ax.set_yscale('log')
plt.scatter(L, dbinder[:,Tc_idx])
plt.plot(L, np.exp(intercept)*L**(slope), ":")

slope_str="{0:.3}".format(slope)
std_str="{0:.3}".format(std_err)
chi_2 = "{0:.3}".format(chi2)
plt.text(16,1,fr"$slope = {slope_str} \pm {std_str}$", fontsize=11)
plt.text(16,9e-1,fr"$\chi^2 = {chi_2}$", fontsize=11)
plt.grid(True, which="both")
plt.xlabel(r"$L$")
plt.ylabel(r"$\langle \frac{d U_L}{d \beta } \rangle$")
plt.title(f"T=1.445")
plt.show()
#fig.savefig("./plots/"+setname+"_nu.svg")
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
print("nu =", nu)
print("nu_u =", nu_u)
# Out:
# nu = 1.2524122915107332
# nu_u = 0.21446551927955723

# %%
gamma = gamma_nu * 1/nu
gamma_u = gamma * np.sqrt((nu_u/nu)**2 + (gamma_nu_u/gamma_nu)**2 )
print("gamma = ", gamma) 
print("gamma_u = ", gamma_u)
# Out:
# gamma =  1.147092207749142
# gamma_u =  0.4703422886859084

# %%
beta = beta_nu * 1/nu
beta_u = beta * np.sqrt( (beta_nu_u/beta_nu)**2 + (nu_u/nu)**2 )
print("beta = ", beta) 
print("beta_u = ", beta_u)
# Out:
# beta =  0.48549874602539295
# beta_u =  0.0878617881047291

# %%
alpha = 2 - 3/nu
alpha_u = 3*nu_u
print("alpha = ", alpha) 
print("alpha_u = ", alpha_u)
# Out:
# alpha =  -0.3953773212982634
# alpha_u =  0.6433965578386717

# %%
delta = 1 + gamma_nu/beta_nu
delta_u = delta * np.sqrt((gamma_nu_u/gamma_nu)**2 + (beta_nu_u/beta_nu)**2)

# %%
print("delta = ", delta) 
print("delta_u = ", delta_u)
# Out:
# delta =  3.3627088991268903
# delta_u =  1.2681826505385168

# %%
eta = 2 - gamma_nu

# %%
print("eta = ", eta) 
print("eta_u = ", gamma_nu_u)
# Out:
# eta =  0.5633676195187913
# eta_u =  0.5352315542421647

# %% [markdown]
# ## Spatial correlation

# %%
r = [[None] * T_num for _ in range(L_num)]
c = [[None] * T_num for _ in range(L_num)]

for i, j in np.ndindex(L_num, T_num):
    r[i][j], c[i][j] = radial_distribution(spatial_correlation_matrix(final_state[i][j]))
# Out:
# ---------------------------------------------------------------------------
# TypingError                               Traceback (most recent call last)
# /tmp/ipykernel_16480/4200853343.py in <module>
#       3
#       4 for i, j in np.ndindex(L_num, T_num):
# ----> 5     r[i][j], c[i][j] = radial_distribution(spatial_correlation_matrix(final_state[i][j]))
#
# ~/anaconda3/lib/python3.9/site-packages/numba/core/dispatcher.py in _compile_for_args(self, *args, **kws)
#     480                 e.patch_message(msg)
#     481
# --> 482             error_rewrite(e, 'typing')
#     483         except errors.UnsupportedError as e:
#     484             # Something unsupported is present in the user code, add help info
#
# ~/anaconda3/lib/python3.9/site-packages/numba/core/dispatcher.py in error_rewrite(e, issue_type)
#     421                 raise e
#     422             else:
# --> 423                 raise e.with_traceback(None)
#     424
#     425         argtypes = []
#
# TypingError: Failed in nopython mode pipeline (step: nopython frontend)
# No implementation of function Function(<function mean at 0x7f4ea80a3f70>) found for signature:
#
#  >>> mean(array(float64, 4d, C), axis=Tuple(Literal[int](0), Literal[int](1), Literal[int](2)))
#
# There are 2 candidate implementations:
#    - Of which 2 did not match due to:
#    Overload in function 'Numpy_method_redirection.generic': File: numba/core/typing/npydecl.py: Line 378.
#      With argument(s): '(array(float64, 4d, C), axis=Tuple(Literal[int](0), Literal[int](1), Literal[int](2)))':
#     Rejected as the implementation raised a specific error:
#       TypingError: numba doesn't support kwarg for mean
#   raised from /home/test/anaconda3/lib/python3.9/site-packages/numba/core/typing/npydecl.py:400
#
# During: resolving callee type: Function(<function mean at 0x7f4ea80a3f70>)
# During: typing of call at /home/test/Documents/p452_project/thermalspin/data_analysis.py (219)
#
#
# File "thermalspin/data_analysis.py", line 219:
# def spatial_correlation_matrix(snapshot):
#     <source elided>
#
#     s = np.mean(snapshot, axis=(0, 1, 2))
#     ^

# %%
fig = plt.figure(figsize=(8,5))
ax = plt.subplot(111)
for i in range(L_num):
    ax.plot(r[i][Tc_idx],c[i][Tc_idx], '--.', label=f"L = {L[i]}")
ax.legend()
ax.set_xlim([0, 5])
plt.ylabel(r"$C(r)$")
plt.xlabel(r"$r$")
plt.title("Spatial correlation")
plt.grid()
plt.show()
#fig.savefig("./plots/"+setname+"_spatial_correlation.svg")
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
rr = [[None] * T_num for _ in range(L_num)]
cc = [[None] * T_num for _ in range(L_num)]

for i, j in np.ndindex(L_num, T_num):
    rr[i][j] = r[i][j][:6]
    cc[i][j] = c[i][j][:6]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_13591/1410741641.py in <module>
#       3
#       4 for i, j in np.ndindex(L_num, T_num):
# ----> 5     rr[i][j] = r[i][j][:6]
#       6     cc[i][j] = c[i][j][:6]
#
# TypeError: 'NoneType' object is not subscriptable

# %%
TT = Tc_idx

fig = plt.figure(figsize=(8,5))
ax = plt.subplot(111)
ax.set_xlim([0,2.4])
for i in range(L_num):
    ax.plot(rr[i][TT], cc[i][TT], '--.', label=f"L = {L[i]}")
ax.set_yscale('log')
ax.legend()
plt.ylabel(r"$\log C(r) $")
plt.xlabel(r"$r$")
plt.title(r"Logarithm of $C(r)$")
plt.grid()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
slope = np.zeros((L_num, T_num))
intercept = np.zeros((L_num, T_num))
for i,j in np.ndindex(L_num, T_num):
    i = int(i)
    j = int(j)
    slope[i,j], intercept[i,j], r_value, p_value, std_err = stats.linregress(rr[i][j], np.nan_to_num(np.log(cc[i][j])))
# Out:
# /tmp/ipykernel_28102/471794171.py:6: RuntimeWarning: invalid value encountered in log
#   slope[i,j], intercept[i,j], r_value, p_value, std_err = stats.linregress(rr[i][j], np.nan_to_num(np.log(cc[i][j])))

# %%
slope[0]
# Out:
# array([-1.31804277, -1.21279635, -1.31135809, -1.36848153, -1.54502086,
#        -1.60973164, -1.88596289, -2.02162262, -1.90075866, -0.67693084])
